# %% [markdown]
# # Name - Vraj Patel

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('D:/SCT_DS_1/pop_data.csv')

# %%
# Displays first 5 rows of the DataFrame
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
# Displays last 5 rows of the DataFrame
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2015        2016        2017        2018        2019        2020  \
# ...

# %%
# Displays the Column name and data type
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# 2024              float64
# Length: 69, dtype: object

# %%
# Displays the shape of the Dataframe
df.shape
# Out:
# (266, 69)

# %%
# Summary statistics
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154023e+08  1.170070e+08  1.191678e+08  1.218381e+08  1.245322e+08
# std    3.616526e+08  3.661347e+08  3.727681e+08  3.813687e+08  3.900162e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.272581e+08  1.301037e+08  1.329570e+08  1.358851e+08  1.389115e+08
# ...

# %%
# Displays column names
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024'],
#       dtype='object')

# %%
# Quick summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
# check for missing values and drop rows containing them
df.isnull().sum()
df = df.dropna()

# %%
# check for duplicates and drop rows containing them
df.duplicated().sum()
df = df.drop_duplicates()

# %%
# Reset index after cleaning
df = df.reset_index(drop=True)

# %%
# List of years 
yearColumns = [str(year) for year in range(1960, 2025)]

# %%
# Histogram for each year
for year in yearColumns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df[year], bins=10, kde=True, color='skyblue')
    plt.title(f'Population Distribution Across Countries in {year}', fontsize=14)
    plt.xlabel('Population')
    plt.ylabel('Number of Countries')
    plt.tight_layout()
    plt.show()

# %%
# Get all year columns
years = df.columns[4:]

# %%
# Total population for each year across all countries
totalValues = df[years].sum()

# Create a bar chart
plt.figure(figsize=(20, 6))  
plt.bar(years, totalValues, color="#97DD1F97")  

# Labels and title
plt.ylabel('Total Population', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.title('Total Population Across All Countries (Per Year)', fontsize=14)
plt.xticks(rotation=90) 

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Top 10 countries with the lowest population in 2024
country2024 = df.sort_values(by='2004').head(10)[['Country Name', 'Country Code', '2004']]
country2024
# Out:
#                   Country Name Country Code     2004
# 243                     Tuvalu          TUV   9816.0
# 178                      Nauru          NRU  10060.0
# 187                      Palau          PLW  19820.0
# 226   Turks and Caicos Islands          TCA  22856.0
# 253     British Virgin Islands          VGB  22881.0
# 84                   Gibraltar          GIB  28715.0
# 210                 San Marino          SMR  29457.0
# 223  Sint Maarten (Dutch part)          SXM  31690.0
# 148                     Monaco          MCO  32307.0
# 146   St. Martin (French part)          MAF  33171.0

# %%
# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=country2024, x='2004', y='Country Name', color='yellow')
plt.title("10 Countries by Lowest Population in 2004")
plt.xlabel("Population")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %%
#Top 10 countries with the Highest population in 2024
country2024 = df.sort_values(by='2004', ascending=False).head(10)[['Country Name', 'Country Code', '2004']]
country2024
# Out:
#                    Country Name Country Code          2004
# 257                       World          WLD  6.492770e+09
# 103            IDA & IBRD total          IBT  5.417128e+09
# 139         Low & middle income          LMY  5.108184e+09
# 155               Middle income          MIC  4.746878e+09
# 102                   IBRD only          IBD  4.168677e+09
# 62   Early-demographic dividend          EAR  2.693185e+09
# 247         Upper middle income          UMC  2.451602e+09
# 138         Lower middle income          LMC  2.295276e+09
# 63          East Asia & Pacific          EAS  2.118748e+09
# 141   Late-demographic dividend          LTE  2.099413e+09

# %%
# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=country2024, x='2004', y='Country Name', color='yellow')
plt.title("10 Countries by Highest Population in 2004")
plt.xlabel("Population")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
